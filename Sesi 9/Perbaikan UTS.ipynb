# %% [markdown]
# 1. Kriteria algoritma adalah memiliki instruksi yang jelas sehingga proses yang dikerjakan tidak ambigu dan membingungkan. Kriteria tersebut adalah..
# Jawab: B.Definiteness

# %% [markdown]
# 2. Berdasarkan flowchart yang ada pada file attachment, Output apakah yang dihasilkan, jika
#
# - umur diisi dengan angka 4
# - tinggi diisi dengan angka 70
#
# ![image.png](attachment:image.png)
#
# Jawab: D. 45000

# %% [markdown]
# 3. Jika terdapat pseudocode seperti berikut ini:
#
# ```
# program salary_counting
#
# declaration:
#    var salary, num_of_work_days, num_off_days, transport_allowance:integer
#    transport_allowance : 20000
# algorithm:
#   read(num_of_work_days,num_off_days); {input user}
#   salary -> num_of_work_days * 300000 - (num_off_days * transport_allowance)
#   salary -> salary - (num_off_days * 300000)
#
#   write(salary)
# ```
#
# Output apakah yang ditampilkan jika num_of_work_days diisi dengan nilai 22 dan num_off_days diisi dengan 5.<br/>
# Jawab: D. 5000000

# %%
num_of_work_days = int(input("num of work: "))
num_off_days = int(input("num off: "))
transport_allowance = 20000

salary = num_of_work_days * 300000 - (num_off_days * transport_allowance)
salary = salary - (num_off_days * 300000)

print(salary)
# Out:
# num of work: 22
# num off: 5
# 5000000

# %% [markdown]
# 4. Pada saat menggunakan IDE Jupyter Notebooks, untuk membuat cell markdown dengan tulisan JUPYTER GOODBOOKS dibawah cell code yang masih dalam keadaan aktif yaitu dengan cara ...<br/>
# Jawab: A. ESCAPE -> B -> M -> ENTER -> JUPYTER GOODBOOKS

# %% [markdown]
# 5. Proses untuk mengidentifikasi sebuah folder agar dilakukan tracking menggunakan git adalah dengan menggunakan perintah<br/>
# Jawab: C. git init

# %% [markdown]
# 6. Berikut ini adalah aturan penamaan variabel yang tepat pada pemrograman python<br/>
# Jawab: E. Nama variabel hanya boleh diawali oleh huruf atau underscore.

# %% [markdown]
# ![image.png](attachment:image.png)
# 7. Output apakah yang dihasilkan, jika kode program seperti pada file attachment di eksekusi<br/>
# Jawab: C. The book with the title 'My Programming is My Adventure' has a price 1000000

# %%
book_title = 'My Programming is My Adventure'
price = 1_000_000
print(f"The book with the title '{book_title}' has a price {price}")
# Out:
# The book with the title 'My Programming is My Adventure' has a price 1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# 8 .Jika terdapat kode program seperti pada file attachment, baris manakah yang menjadi penyebab error?<br/>
# Jawab: A. 3 dan 5

# %% [markdown]
# ![image.png](attachment:image.png)
# 9. Output apakah yang ditampilkan pada kode program seperti pada file attachment<br/>
# Jawab: B. 0 True True True

# %%
x = 10
y = 20
z = 200

print(y % x, end=' ')
print(x < y, end=' ')
print(z==y*x, end=' ')
print(not(not(y > x)), end=' ')
# Out:
# 0 True True True

# %% [markdown]
# 10. Hasil output apakah yang dihasilkan jika terdapat angka dengan nilai = 255 kemudian dioperasikan AND dengan nilai = 15 ?<br/>
# Jawab: C.15

# %%
print(255 and 15)
# Out:
# 15

# %% [markdown]
# 11. Terdapat variabel seperti berikut ini:
#
# ```
# address = "Jalan Cibolang Kaler Nomor 21"
# ```
#
# jika output yang diinginkan adalah jC maka proses pada kode program manakah yang benar?

# %%
address = "Jalan Cibolang Kaler Nomor 21"
c1 = address[0].lower()
c2 = address[6]
print(c1 + c2)
# Out:
# jC

# %% [markdown]
# 12. Setiap kondisi yang dilakukan pengecekan pada percabangan, pasti akan berisikan operator ...<br/>
# Jawab: B. Perbandingan

# %% [markdown]
# 13. Manakah pernyataan berikut ini yang paling tepat?<br/>
# Jawab: C. kode if boleh diletakkan di dalam if dengan menggunakan indentasi/TAB

# %% [markdown]
# ![image.png](attachment:image.png)
# 14. Output apakah yang ditampilkan jika kode program seperti pada file attachment dieksekusi?<br/>
# Jawab: A. winger defender keeper

# %%
number_of_player = 40
position = ''
if number_of_player <40:
    if number_of_player % 4 == 0:
        position += ' playmaker '
    else:
        position += ' attacker '
else:
    if number_of_player % 4 == 0:
        position += ' winger '
    if number_of_player % 10 == 0:
        position += ' defender '
    if number_of_player == 40:
        position += ' keeper '
        
print(position)
# Out:
#  winger  defender  keeper

# %% [markdown]
# ![image.png](attachment:image.png)
# 15. Jika output kode program pada file attachment yang diinginkan adalah winger defender , maka nilai dari number_of_player diganti dengan<br/>
# Jawab: E. 80

# %%
number_of_player = 80
position = ''
if number_of_player <40:
    if number_of_player % 4 == 0:
        position += ' playmaker '
    else:
        position += ' attacker '
else:
    if number_of_player % 4 == 0:
        position += ' winger '
    if number_of_player % 10 == 0:
        position += ' defender '
    if number_of_player == 40:
        position += ' keeper '
        
print(position)
# Out:
#  winger  defender

# %% [markdown]
# 16. Looping for digunakan pada saat ..<br/>
# Jawab: B. Permasalahan perulangan telah diketahui batas awal dan batas akhirnya

# %% [markdown]
# 17. Ciri-ciri dari looping while adalah ...<br/>
# Jawab: D. Terdapat statement yang akan mengubah nilai kondisi pada while menjadi False

# %% [markdown]
# ![image.png](attachment:image.png)
# 18. Output apakah yang dihasilkan, jika kode program seperti pada file attachment dieksekusi<br/>
# Jawab: A. 20

# %%
for i in range(5,1,-1):
    pass
print(i * 10, end=' ')
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:image.png)
# 19. Output apakah yang dihasilkan, jika kode program seperti pada file attachment dieksekusi<br/>
# jawab: D. 5 35

# %%
for i in range(1,10,3):
    if i == 4:
        continue
    print(i * 5, end = ' ')
# Out:
# 5 35

# %% [markdown]
# 20. Jika terdapat kode program seperti pada file attachment
# ![image.png](attachment:image.png)
# Output apakah yang dihasilkan, jika kode program tersebut dieksekusi?<br/>
# Jawab: E. Program akan menampilkan nilai yang berkurang 1 terus menerus tak hingga (infinite loop)

# %%
number = 0
while number < 10:
    number -= 1
    print(number)

# %% [markdown]
# Essay 1. Buatlah program untuk mengecek bahwa sebuah email termasuk valid atau tidak . Valid diartikan True dan tidak valid diartikan False. Program dibuat dengan menggunakan string method tanpa condition (if) . Berikut contoh test case yang bisa digunakan sebagai acuan:
#
# input : alunsujjada@gmailcom
# output : False
# ------------------------------------------
# input : alunsujjada@gmail.com
# output : True
# ------------------------------------------
# input : alun.sujjada@gmail.com
# output : False
# ------------------------------------------
# input : alunsujjada.gmail.com
# output : False
# ------------------------------------------
# input : alun.sujjada@gmailcom
# output : False
#
# Clue : Gunakan pencarian posisi

# %%
def isEmailValid(email):
    pos_at = email.find("@")
    pos_dot = email.find(".")
    
    return (pos_at >= 0 and pos_dot >= 0 and (pos_at < pos_dot))

print("Test case")
emails = ['alunsujjada@gmailcom', 'alunsujjada@gmail.com', 'alun.sujjada@gmail.com', 'alunsujjada.gmail.com', 'alun.sujjada@gmailcom']

for email in emails:
    valid = isEmailValid(email)
    print(f"{email} => {valid}")
    
print("\nTest case custom input")
email = input("Masukan email: ")
valid = isEmailValid(email)

print(f"{email} => {valid}")
# Out:
# Test case
# alunsujjada@gmailcom => False
# alunsujjada@gmail.com => True
# alun.sujjada@gmail.com => False
# alunsujjada.gmail.com => False
# alun.sujjada@gmailcom => False
#
# Test case custom input
# Masukan email: pardiwan@gmail.com
# pardiwan@gmail.com => True

# %% [markdown]
# Essay 2. Buatlah program dengan menggunakan kondisi perulangan dan percabangan untuk melakukan penyandian huruf pada sebuah kalimat yaitu dengan ketentuan sebagai berikut.
#
# * mengganti huruf a atau A dengan 4
# * mengganti huruf e atau E dengan 3
# * mengganti huruf L dengan 7
# * mengganti huruf S dengan 5
#
# Contoh:
# * input : BELAJAR Pemrograman Python Sangat Mudah sekali
# * output : B374J4R P3mrogr4m4n Python 54ng4t Mud4h s3k4li
#
#
# * input : Looping For digunakan ketika sudah diketahui batas Awal dan Batas Akhir
# * output : 7ooping For digun4k4n k3tik4 sud4h dik3t4hui b4t4s 4w4l d4n B4t4s 4khir

# %%
kalimat = input("isikan kalimat anda : ")
sandi = ''

for i in range(len(kalimat)):
    huruf = kalimat[i]
    if huruf == 'a' or huruf == 'A':
        sandi += "4"
    elif huruf == 'e' or huruf == 'E':
        sandi += '3'
    elif huruf == 'L':
        sandi += '7'
    elif huruf == 'S':
        sandi += '5'
    else:
        sandi += huruf
        
print(sandi)
# Out:
# isikan kalimat anda : Looping For digunakan ketika sudah diketahui batas Awal dan Batas Akhir
# 7ooping For digun4k4n k3tik4 sud4h dik3t4hui b4t4s 4w4l d4n B4t4s 4khir
